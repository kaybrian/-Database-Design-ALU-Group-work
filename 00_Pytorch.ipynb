# %% [markdown]
# <a href="https://colab.research.google.com/github/kaybrian/-Database-Design-ALU-Group-work/blob/main/00_Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## 00 pytorch Fundamentals
# Out:
# new place to get started
